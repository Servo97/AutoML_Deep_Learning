# %%
from autogluon import TabularPrediction as task

predictor = task.fit(train_data=task.Dataset(file_path='/home/user/Sarvesh/Baap_Product/AutoML_DL/security/CICIDS2017/combined_data_train.csv'), 
#                      hyperparameter_tune=True, 
#                      search_strategy="skopt" ,
                     label="Label")
predictions = predictor.predict(task.Dataset(file_path='/home/user/Sarvesh/Baap_Product/AutoML_DL/security/CICIDS2017/combined_data_test.csv'))
# Out:
# /home/user/anaconda3/envs/py37/lib/python3.7/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# Loaded data from: /home/user/Sarvesh/Baap_Product/AutoML_DL/security/CICIDS2017/combined_data_train.csv | Columns = 79 / 79 | Rows = 2262300 -> 2262300
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20200515_122945/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20200515_122945/
# Train Data Rows:    2262300
# Train Data Columns: 79
# Preprocessing data ...
# Here are the first 10 unique label values in your data:  ['DoS_attack' 'BENIGN' 'DDos_attack' 'PortScan' 'brute_force_attack'
#  'botnet_attack' 'web_attack' 'infiltration_attack']
# AutoGluon infers your prediction problem is: multiclass  (because dtype of label-column == object).
# ...

# %%
predictor.feature_importance()
# Out:
# Computing raw permutation importance for 70 features on weighted_ensemble_k0_l1 ...
# 	457.19s	= Expected runtime
# 	556.54s	= Actual runtime
# Destination Port               0.0655
# Init_Win_bytes_forward         0.0525
# Init_Win_bytes_backward        0.0077
# Fwd IAT Min                    0.0074
# Bwd Packet Length Std          0.0069
# Flow IAT Mean                  0.0062
# Idle Max                       0.0047
# Fwd Header Length              0.0046
# Flow Bytes/s                   0.0044
# Bwd Packets/s                  0.0029
# Flow Packets/s                 0.0029
# Flow IAT Max                   0.0029
# Fwd Packets/s                  0.0028
# min_seg_size_forward           0.0028
# Flow IAT Min                   0.0027
# Flow Duration                  0.0023
# Fwd IAT Std                    0.0022
# Bwd IAT Mean                   0.0022
# Bwd Header Length              0.0021
# Bwd IAT Total                  0.0018
# Average Packet Size            0.0017
# ...

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, r2_score, f1_score
import numpy as np
import scipy.stats as stats
df = pd.read_csv('/home/user/Sarvesh/Baap_Product/AutoML_DL/security/CICIDS2017/combined_data_test.csv')
df['Label'] = df['Label'].fillna(stats.stats.mode(df['Label'])[0][0])
tgt = df['Label'].values
# print(tgt)
predictions
# print(predictions)
pred_df = pd.DataFrame(classification_report(tgt, predictions, output_dict=True))
pred_df
# Out:
# /home/user/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   BENIGN   DDos_attack    DoS_attack      PortScan  \
# f1-score        0.999430      0.999631      0.998297      0.997199
# precision       0.999460      1.000000      0.998566      0.994848
# recall          0.999399      0.999263      0.998029      0.999561
# support    454094.000000  25786.000000  50227.000000  31877.000000
#
#            botnet_attack  brute_force_attack  infiltration_attack  web_attack  \
# f1-score        0.811665            0.998349                  0.0    0.981862
# precision       0.874346            1.000000                  0.0    0.985437
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(tgt,predictions)
